# %%
import numpy as np
import pandas as pd
from tensorflow import keras
import tensorflow as tf
import os
import joblib
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow
from sklearn.preprocessing import StandardScaler

# %%
(X_train,y_train) , (X_test,y_test) = keras.datasets.mnist.load_data()

# %%
plt.matshow(X_train[2])

# %%
X_train = X_train/255                #scaling
X_test = X_test/255

# %%
# X_train_flattened = X_train.reshape(len(X_train),28*28)
X_test_flattened = X_test.reshape(len(X_test),28*28)

# %%
# model = keras.Sequential([            no hidden layers
#     keras.layers.Dense(10,input_shape=(784,),activation='sigmoid')
# ])

# model.compile(
#     optimizer='adam',
#     loss='sparse_categorical_crossentropy',
#     metrics=['accuracy']
# )

model = keras.Sequential([                     #has hidden layers
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(X_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9201 - loss: 0.2806
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9632 - loss: 0.1270
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9743 - loss: 0.0881
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9798 - loss: 0.0667
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9835 - loss: 0.0527

# %%
joblib.dump(model,'Hand_Written_Digits')
# Out:
# ['Hand_Written_Digits']

# %%
plt.matshow(X_test[21])

# %%
y_predicted = model.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
np.argmax(y_predicted[21])
# Out:
# np.int64(6)
